# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load results
results = pd.read_csv("../evaluation/results_german.csv", index_col=0)
results.index = results.index.astype(str)

print(results)

# Only plot if classes exist
classes = ["1", "2"]
existing = [cls for cls in classes if cls in results.index]

if existing:
    results.loc[existing, ["precision", "recall", "f1-score"]].plot(
        kind="bar",
        figsize=(6, 4),
        title="German Credit Risk - Metrics"
    )
    plt.ylabel("Score")
    plt.ylim(0, 1)
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ No matching classes found in results.")
# Out:
#               precision    recall  f1-score     support   roc_auc
# 1              0.847682  0.859060  0.853333  149.000000  0.921564
# 2              0.837209  0.824427  0.830769  131.000000  0.921564
# accuracy       0.842857  0.842857  0.842857    0.842857  0.921564
# macro avg      0.842446  0.841744  0.842051  280.000000  0.921564
# weighted avg   0.842782  0.842857  0.842777  280.000000  0.921564
